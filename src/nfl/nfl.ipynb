# %%
import nfl_app

# %%
stadium_details = nfl_app.download_nfl_data()
# Out:
# 2023-09-03 20:53:13.885 | INFO     | nfl_app:download_nfl_data:41 - URL Access Successful

# %%
stadium_details
# Out:
# [{'GameKey': '202210132',
#   'SeasonType': 1,
#   'Season': 2022,
#   'Week': 1,
#   'Date': '2022-09-08T20:20:00',
#   'AwayTeam': 'BUF',
#   'HomeTeam': 'LAR',
#   'AwayScore': 35,
#   'HomeScore': 11,
#   'Channel': 'NBC',
#   'PointSpread': 1.9,
#   'OverUnder': 59.0,
#   'Quarter': 'F',
#   'TimeRemaining': None,
#   'Possession': None,
#   'Down': None,
#   'Distance': 'Scrambled',
#   'YardLine': None,
#   'YardLineTerritory': None,
#   'RedZone': None,
#   'AwayScoreQuarter1': 9,
#   'AwayScoreQuarter2': 4,
#   'AwayScoreQuarter3': 9,
#   'AwayScoreQuarter4': 16,
#   'AwayScoreOvertime': 0,
#   'HomeScoreQuarter1': 0,
#   'HomeScoreQuarter2': 11,
#   'HomeScoreQuarter3': 0,
#   'HomeScoreQuarter4': 0,
#   'HomeScoreOvertime': 0,
#   'HasStarted': True,
#   'IsInProgress': False,
#   'IsOver': True,
#   'Has1stQuarterStarted': True,
#   'Has2ndQuarterStarted': True,
#   'Has3rdQuarterStarted': True,
#   'Has4thQuarterStarted': True,
#   'IsOvertime': False,
# ...
